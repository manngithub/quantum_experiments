# %% [raw]
# Source: https://github.com/atilsamancioglu/QX06-BernsteinVaziraniAlgorithmComplete

# %%
from qiskit import *

# %%
# %matplotlib inline
from qiskit.tools.visualization import plot_histogram

# %%
secretNumber = '10101010100'

# %%
circuit = QuantumCircuit(len(secretNumber)+1,len(secretNumber))

# %%
circuit.h(range(len(secretNumber)))
circuit.x(len(secretNumber))
circuit.h(len(secretNumber))

circuit.barrier()

for index, one in enumerate(reversed(secretNumber)):
    print(f"index{index} is {one}")
    if one == "1":
        circuit.cx(index,len(secretNumber))

circuit.barrier()

circuit.h(range(len(secretNumber)))

circuit.barrier()

circuit.measure(range(len(secretNumber)),range(len(secretNumber)))
# Out:
# index0 is 0
# index1 is 0
# index2 is 1
# index3 is 0
# index4 is 1
# index5 is 0
# index6 is 1
# index7 is 0
# index8 is 1
# index9 is 0
# index10 is 1

# %%
circuit.draw(output='mpl')

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend=simulator, shots=1).result()
counts = result.get_counts()
print(counts)
# Out:
# {'10101010100': 1}

# %%
plot_histogram([counts])
